# %% [markdown]
# ## Random Forest
#
# Random Forest is an ensemble of Decision Trees. With a few exceptions, a `RandomForestClassifier` has all the hyperparameters of a `DecisionTreeClassifier` (to control how trees are grown), plus all the hyperparameters of a `BaggingClassifier` to control the ensemble itself.
#
# The Random Forest algorithm introduces extra randomness when growing trees; instead of searching for the very best feature when splitting a node, it searches for the best feature among a random subset of features. This results in a greater tree diversity, which (once again) trades a higher bias for a lower variance, generally yielding an overall better model. The following `BaggingClassifier` is roughly equivalent to the previous `RandomForestClassifier`. Run the cell below to visualize a single estimator from a random forest model, using the Iris dataset to classify the data into the appropriate species.

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# Model (can also use single decision tree)
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=10)

# Train
model.fit(iris.data, iris.target)
# Extract single tree
estimator = model.estimators_[5]

from sklearn.tree import export_graphviz
# Export as dot file
export_graphviz(estimator, out_file='tree.dot', 
                feature_names = iris.feature_names,
                class_names = iris.target_names,
                rounded = True, proportion = False, 
                precision = 2, filled = True)

# Convert to png using system command (requires Graphviz)
from subprocess import call
call(['dot', '-Tpng', 'tree.dot', '-o', 'tree.png', '-Gdpi=600'])

# Display in jupyter notebook
from IPython.display import Image
Image(filename = 'tree.png')

# %% [markdown]
# Notice how each split separates the data into buckets of similar observations. This is a single tree and a relatively simple classification dataset, but the same method is used in a more complex dataset with greater depth to the trees.

# %% [markdown]
# ## Coronavirus
# Coronavirus disease (COVID-19) is an infectious disease caused by a new virus.
# The disease causes respiratory illness (like the flu) with symptoms such as a cough, fever, and in more severe cases, difficulty breathing. You can protect yourself by washing your hands frequently, avoiding touching your face, and avoiding close contact (1 meter or 3 feet) with people who are unwell. An outbreak of COVID-19 started in December 2019 and at the time of the creation of this project was continuing to spread throughout the world. Many governments recommended only essential outings to public places and closed most business that do not serve food or sell essential items. An excellent [spatial dashboard](https://www.arcgis.com/apps/opsdashboard/index.html#/bda7594740fd40299423467b48e9ecf6) built by Johns Hopkins shows the daily confirmed cases by country.
#
# This case study was designed to drive home the important role that data science plays in real-world situations like this pandemic. This case study uses the Random Forest Classifier and a dataset from the South Korean cases of COVID-19 provided on [Kaggle](https://www.kaggle.com/kimjihoo/coronavirusdataset) to encourage research on this important topic. The goal of the case study is to build a Random Forest Classifier to predict the 'state' of the patient.

# %% [markdown]
# First, please load the needed packages and modules into Python. Next, load the data into a pandas dataframe for ease of use.

# %%
import os
import pandas as pd
from datetime import datetime,timedelta
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from plotly import graph_objs as go
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import ExtraTreesRegressor

# %%
url ='SouthKoreacoronavirusdataset/PatientInfo.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    patient_id  global_num     sex  birth_year  age country province  \
# 0  1000000001         2.0    male      1964.0  50s   Korea    Seoul
# 1  1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2  1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3  1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4  1000000005         9.0  female      1992.0  20s   Korea    Seoul
#
#           city disease        infection_case  infection_order   infected_by  \
# 0   Gangseo-gu     NaN       overseas inflow              1.0           NaN
# 1  Jungnang-gu     NaN       overseas inflow              1.0           NaN
# 2    Jongno-gu     NaN  contact with patient              2.0  2.002000e+09
# 3      Mapo-gu     NaN       overseas inflow              1.0           NaN
# 4  Seongbuk-gu     NaN  contact with patient              2.0  1.000000e+09
#
#    contact_number symptom_onset_date confirmed_date released_date  \
# ...

# %%
df.shape
# Out:
# (2218, 18)

# %%
#Counts of null values 
na_df=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)).reset_index()
na_df.columns = ['VarName', 'NullCount']
na_df[(na_df['NullCount']>0)]
# Out:
#                VarName  NullCount
# 0              disease       2199
# 1        deceased_date       2186
# 2      infection_order       2176
# 3   symptom_onset_date       2025
# 4        released_date       1995
# 5       contact_number       1807
# 6          infected_by       1749
# 7       infection_case       1055
# 8           global_num        904
# 9           birth_year        454
# 10                 age        261
# 11                 sex        145
# 12      confirmed_date        141
# 13               state         88
# 14                city         65

# %%
#counts of response variable values
df.state.value_counts()
# Out:
# isolated    1791
# released     307
# deceased      32
# Name: state, dtype: int64

# %% [markdown]
#  **<font color='teal'> Create a new column named 'n_age' which is the calculated age based on the birth year column.</font>**

# %% [markdown]
# **Personal insight:**
#
# Since there are 454 missing values for **birth_year**, I think it're reasonable to see how are we going to fill those missing values, before creating the new feature.
# Since there are only 261 missing **ages**, we can clearly see there are records that have **age**, but no **birth_year**. So using total average would be a mistake
# We can instead use an aproximation. For example: we will asume that a person whos is in their 60s without a year of birth
# will have 65 years old, therefore born in 2020-65 = 1955
#
# We wil also do the reverse process. If there will be records without **age** but with **birth_year**, we will fill those records with the apropiate category.

# %%
# Step 1, let's see how many records are missing both age and birth_year.
# It's fair to say that for these we have no way to make a deduction on their age, so we'll use the overall average to get the birth year

condition = df.birth_year.isnull() & df.age.isnull() #151 records
avg_birth_year = df['birth_year'].mean() # 1974.9886621315193
df.loc[condition,'birth_year'] = avg_birth_year

# %%
# Step 2, let's use the asumption to update the age group for those 151 records
df.loc[condition,'age'] = '40s'

# %%
# Now we shouldn't have any records missing both age and birth_year
df[df.birth_year.isnull() & df.age.isnull()]
# Out:
# Empty DataFrame
# Columns: [patient_id, global_num, sex, birth_year, age, country, province, city, disease, infection_case, infection_order, infected_by, contact_number, symptom_onset_date, confirmed_date, released_date, deceased_date, state]
# Index: []

# %%
na_df=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)).reset_index()
na_df.columns = ['VarName', 'NullCount']
na_df[(na_df['NullCount']>0)]
# Out:
#                VarName  NullCount
# 0              disease       2199
# 1        deceased_date       2186
# 2      infection_order       2176
# 3   symptom_onset_date       2025
# 4        released_date       1995
# 5       contact_number       1807
# 6          infected_by       1749
# 7       infection_case       1055
# 8           global_num        904
# 9           birth_year        303
# 10                 sex        145
# 11      confirmed_date        141
# 12                 age        110
# 13               state         88
# 14                city         65

# %%
# Step 3. Replacing ages according to birth_year.
# this proved to be a bit difficult, because I thought I had to update just the missing values.
# but there are several ways to do it: 1. replace all the age groups based on existent birth_year. 2 order it by birth_year and use ffill

sorted_df = df.sort_values(by = ['birth_year', 'age'])
sorted_df['age'].fillna(method = 'ffill', inplace = True)
df = sorted_df.sort_index()

# %%
na_df=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)).reset_index()
na_df.columns = ['VarName', 'NullCount']
na_df
# Out:
#                VarName  NullCount
# 0              disease       2199
# 1        deceased_date       2186
# 2      infection_order       2176
# 3   symptom_onset_date       2025
# 4        released_date       1995
# 5       contact_number       1807
# 6          infected_by       1749
# 7       infection_case       1055
# 8           global_num        904
# 9           birth_year        303
# 10                 sex        145
# 11      confirmed_date        141
# 12               state         88
# 13                city         65
# 14                 age          0
# 15             country          0
# 16            province          0
# 17          patient_id          0

# %%
df.age.value_counts()
# Out:
# 20s     479
# 40s     470
# 50s     409
# 30s     274
# 60s     248
# 70s     124
# 80s      85
# 10s      79
# 0s       32
# 90s      17
# 100s      1
# Name: age, dtype: int64

# %%
#Step 4. Filling missing birth_year according to their age class. First we'll create the needed dictionary, then we'll fill the missing birth_years with the age class
age_dict = {'0s': 2015, '10s': 2005, '20s':1995, '30s': 1985, '40s': 1975, 
            '50s': 1965, '60s': 1955, '70s': 1945, '80s': 1935, '90s': 1925, '100s': 1915}
df.birth_year.fillna(df.age, inplace = True)

# %%
# Finnaly we use the dictionary to update the birth_year
df.birth_year.replace(age_dict, inplace = True)

# %%
df.age.unique(), df.birth_year.unique()
# Out:
# (array(['50s', '30s', '20s', '60s', '80s', '70s', '40s', '10s', '90s',
#         '0s', '100s'], dtype=object),
#  array([1964.        , 1987.        , 1991.        , 1992.        ,
#         1966.        , 1995.        , 1983.        , 1960.        ,
#         1962.        , 1938.        , 1952.        , 1943.        ,
#         1945.        , 1944.        , 2000.        , 1941.        ,
#         1936.        , 1985.        , 1961.        , 1980.        ,
#         1958.        , 1986.        , 1968.        , 1950.        ,
#         1954.        , 1965.        , 1970.        , 1984.        ,
#         1963.        , 1976.        , 1953.        , 1977.        ,
#         1979.        , 1999.        , 1993.        , 1956.        ,
#         1994.        , 1973.        , 1937.        , 1946.        ,
#         1990.        , 1935.        , 1955.        , 1974.        ,
#         1975.        , 1967.        , 1982.        , 2003.        ,
# ...

# %%
# Now we can create the n_age feature
df['n_age'] = (2020 - df['birth_year'])
df.n_age.value_counts()
# Out:
# 45.011338     151
# 25.000000     130
# 55.000000      93
# 45.000000      74
# 35.000000      73
#              ...
# 9.000000        2
# 0.000000        2
# 93.000000       2
# 104.000000      1
# 89.000000       1
# Name: n_age, Length: 97, dtype: int64

# %% [markdown]
# ### Handle Missing Values

# %% [markdown]
#  **<font color='teal'> Print the number of missing values by column.</font>**

# %%
na_df=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)).reset_index()
na_df.columns = ['VarName', 'NullCount']
na_df
# Out:
#                VarName  NullCount
# 0              disease       2199
# 1        deceased_date       2186
# 2      infection_order       2176
# 3   symptom_onset_date       2025
# 4        released_date       1995
# 5       contact_number       1807
# 6          infected_by       1749
# 7       infection_case       1055
# 8           global_num        904
# 9                  sex        145
# 10      confirmed_date        141
# 11               state         88
# 12                city         65
# 13          birth_year          0
# 14               n_age          0
# 15                 age          0
# 16             country          0
# 17            province          0
# 18          patient_id          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2218 entries, 0 to 2217
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          2218 non-null   int64
#  1   global_num          1314 non-null   float64
#  2   sex                 2073 non-null   object
#  3   birth_year          2218 non-null   float64
#  4   age                 2218 non-null   object
#  5   country             2218 non-null   object
#  6   province            2218 non-null   object
#  7   city                2153 non-null   object
#  8   disease             19 non-null     object
#  9   infection_case      1163 non-null   object
#  10  infection_order     42 non-null     float64
#  11  infected_by         469 non-null    float64
#  12  contact_number      411 non-null    float64
#  13  symptom_onset_date  193 non-null    object
#  14  confirmed_date      2077 non-null   object
# ...

# %% [markdown]
#  **<font color='teal'> Fill the 'disease' missing values with 0 and remap the True values to 1.</font>**

# %%
df['disease'] = df['disease'].replace(True,1)
df['disease'] = df['disease'].fillna(0)
df.disease.unique()
# Out:
# array([0., 1.])

# %% [markdown]
#  **<font color='teal'> Fill null values in the following columns with their mean: 'global_number','birth_year','infection_order','infected_by'and 'contact_number'</font>**

# %% [markdown]
# **Personal insight:**
#
# The features that have a lot of missing data can also become irelevant.
# So we'll keep questions marks over:
# *	symptom_onset_date	- 2025
# *	released_date	- 1995
# *	contact_number	- 1807
# *	infected_by	- 1749
#
# And we should not take into account:
# *	deceased_date	- 2186
# *	infection_order	- 2176

# %%
# doing some exploratory analysis so I can understand why we're averaging the next 4 features to fill NaNs
df[df.global_num.isnull()].index, df[df.infection_order.notna()]
# Out:
# (Int64Index([ 217,  282,  283,  284,  285,  286,  287,  288,  289,  290,
#              ...
#              2204, 2205, 2206, 2207, 2208, 2209, 2210, 2211, 2212, 2213],
#             dtype='int64', length=904),
#        patient_id  global_num     sex  birth_year  age country  \
#  0     1000000001         2.0    male      1964.0  50s   Korea
#  1     1000000002         5.0    male      1987.0  30s   Korea
#  2     1000000003         6.0    male      1964.0  50s   Korea
#  3     1000000004         7.0    male      1991.0  20s   Korea
#  4     1000000005         9.0  female      1992.0  20s   Korea
#  5     1000000006        10.0  female      1966.0  50s   Korea
#  6     1000000007        11.0    male      1995.0  20s   Korea
#  7     1000000008        13.0    male      1992.0  20s   Korea
#  8     1000000009        19.0    male      1983.0  30s   Korea
#  9     1000000010        21.0  female      1960.0  60s   Korea
#  10    1000000011        23.0  female      1962.0  50s   China
# ...

# %%
# We took care of 'birth_year' already
df['global_num'].fillna(df['global_num'].mean(), inplace = True)
df['infection_order'].fillna(df['infection_order'].mean(), inplace = True)
df['infected_by'].fillna(df['infected_by'].mean(), inplace = True)
df['contact_number'].fillna(df['contact_number'].mean(), inplace = True)

# %% [markdown]
#  **<font color='teal'> Fill the rest of the missing values with any method.</font>**

# %%
na_df=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)).reset_index()
na_df.columns = ['VarName', 'NullCount']
na_df
# Out:
#                VarName  NullCount
# 0        deceased_date       2186
# 1   symptom_onset_date       2025
# 2        released_date       1995
# 3       infection_case       1055
# 4                  sex        145
# 5       confirmed_date        141
# 6                state         88
# 7                 city         65
# 8              country          0
# 9           global_num          0
# 10          birth_year          0
# 11                 age          0
# 12               n_age          0
# 13            province          0
# 14             disease          0
# 15     infection_order          0
# 16         infected_by          0
# 17      contact_number          0
# 18          patient_id          0

# %%
# we'll replace the missing cities, sex, infection_case and state with 'Unknown'
df['city'].fillna('Unknown', inplace = True)
df['infection_case'].fillna('Unknown', inplace = True)
df['sex'].fillna('Unknown', inplace = True)
df['state'].fillna('Unknown', inplace = True)

# %% [markdown]
#  **<font color='teal'> Check for any remaining null values.</font>**

# %%
na_df=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)).reset_index()
na_df.columns = ['VarName', 'NullCount']
na_df
# Out:
#                VarName  NullCount
# 0        deceased_date       2186
# 1   symptom_onset_date       2025
# 2        released_date       1995
# 3       confirmed_date        141
# 4                n_age          0
# 5             province          0
# 6           global_num          0
# 7                  sex          0
# 8           birth_year          0
# 9                  age          0
# 10             country          0
# 11      infection_case          0
# 12                city          0
# 13             disease          0
# 14               state          0
# 15     infection_order          0
# 16         infected_by          0
# 17      contact_number          0
# 18          patient_id          0

# %%
df.head()
# Out:
#    patient_id  global_num     sex  birth_year  age country province  \
# 0  1000000001         2.0    male      1964.0  50s   Korea    Seoul
# 1  1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2  1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3  1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4  1000000005         9.0  female      1992.0  20s   Korea    Seoul
#
#           city  disease        infection_case  infection_order   infected_by  \
# 0   Gangseo-gu      0.0       overseas inflow              1.0  2.600789e+09
# 1  Jungnang-gu      0.0       overseas inflow              1.0  2.600789e+09
# 2    Jongno-gu      0.0  contact with patient              2.0  2.002000e+09
# 3      Mapo-gu      0.0       overseas inflow              1.0  2.600789e+09
# 4  Seongbuk-gu      0.0  contact with patient              2.0  1.000000e+09
#
#    contact_number symptom_onset_date confirmed_date released_date  \
# ...

# %% [markdown]
# Remove date columns from the data.

# %%
df = df.drop(['symptom_onset_date','confirmed_date','released_date','deceased_date'],axis =1)

# %% [markdown]
# Review the count of unique values by column.

# %%
print(df.nunique())
# Out:
# patient_id         2218
# global_num         1304
# sex                   3
# birth_year           97
# age                  11
# country               4
# province             17
# city                135
# disease               2
# infection_case       17
# infection_order       7
# infected_by         207
# contact_number       73
# state                 4
# n_age                97
# dtype: int64

# %% [markdown]
# Review the percent of unique values by column.

# %%
print(df.nunique()/df.shape[0])
# Out:
# patient_id         1.000000
# global_num         0.587917
# sex                0.001353
# birth_year         0.043733
# age                0.004959
# country            0.001803
# province           0.007665
# city               0.060866
# disease            0.000902
# infection_case     0.007665
# infection_order    0.003156
# infected_by        0.093327
# contact_number     0.032913
# state              0.001803
# n_age              0.043733
# dtype: float64

# %% [markdown]
# Review the range of values per column.

# %%
df.describe().T
# Out:
#                   count          mean           std           min  \
# patient_id       2218.0  4.014678e+09  2.192419e+09  1.000000e+09
# global_num       2218.0  4.664817e+03  2.211785e+03  1.000000e+00
# birth_year       2218.0  1.975058e+03  1.867849e+01  1.916000e+03
# disease          2218.0  8.566276e-03  9.217769e-02  0.000000e+00
# infection_order  2218.0  2.285714e+00  1.706622e-01  1.000000e+00
# infected_by      2218.0  2.600789e+09  7.216328e+08  1.000000e+09
# contact_number   2218.0  2.412895e+01  3.917141e+01  0.000000e+00
# n_age            2218.0  4.494216e+01  1.867849e+01  0.000000e+00
#
#                           25%           50%           75%           max
# patient_id       1.700000e+09  6.001000e+09  6.004000e+09  7.000000e+09
# global_num       4.205250e+03  4.664817e+03  5.900250e+03  8.717000e+03
# birth_year       1.963000e+03  1.974989e+03  1.992000e+03  2.020000e+03
# disease          0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# ...

# %% [markdown]
# ### Check for duplicated rows

# %%
duplicateRowsDF = df[df.duplicated()]
duplicateRowsDF
# Out:
# Empty DataFrame
# Columns: [patient_id, global_num, sex, birth_year, age, country, province, city, disease, infection_case, infection_order, infected_by, contact_number, state, n_age]
# Index: []

# %% [markdown]
# Print the categorical columns and their associated levels.

# %%
dfo = df.select_dtypes(include=['object'], exclude=['datetime'])
dfo.shape
#get levels for all variables
vn = pd.DataFrame(dfo.nunique()).reset_index()
vn.columns = ['VarName', 'LevelsCount']
vn.sort_values(by='LevelsCount', ascending =False)
vn
# Out:
#           VarName  LevelsCount
# 0             sex            3
# 1             age           11
# 2         country            4
# 3        province           17
# 4            city          135
# 5  infection_case           17
# 6           state            4

# %% [markdown]
# **<font color='teal'> Plot the correlation heat map for the features.</font>**

# %%
sns.heatmap(df.corr(), cmap='RdYlGn')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **<font color='teal'> Plot the boxplots to check for outliers. </font>**

# %%
sns.boxplot(data = df)
# Out:
# <AxesSubplot:>

# %%
sns.set(rc={'figure.figsize':(15,12)}, font_scale = 1)
plt.subplot(2,4,1)
sns.boxplot(y= 'patient_id', data = df)
plt.subplot(2,4,2)
sns.boxplot(y= 'global_num', data = df)
plt.subplot(2,4,3)
sns.boxplot(y= 'birth_year', data = df)
plt.subplot(2,4,4)
sns.boxplot(y= 'disease', data = df)
plt.subplot(2,4,5)
sns.boxplot(y= 'infection_order', data = df)
plt.subplot(2,4,6)
sns.boxplot(y= 'infected_by', data = df)
plt.subplot(2,4,7)
sns.boxplot(y= 'contact_number', data = df)
plt.subplot(2,4,8)
sns.boxplot(y= 'n_age', data = df)
# Out:
# <AxesSubplot:ylabel='n_age'>

# %% [markdown]
# **<font color='teal'> Create dummy features for object type features. </font>**

# %%
df_num = pd.get_dummies(df, drop_first = True)
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2218 entries, 0 to 2217
# Columns: 192 entries, patient_id to state_released
# dtypes: float64(7), int64(1), uint8(184)
# memory usage: 634.5 KB

# %% [markdown]
# **Questions**
#
# I don't understand why we are doing the dummies when we are still having **y** in our data.
#
# Secondly, why are we creating 4 target classes, when we actually have 3 classes and missing data?
# Shouldn't we use missing data as y_test to predict what classes are these first?

# %%
# getting target out of data
y = df['state']

#getting X out of data, and applying get_dummies
X = df.drop('state', axis = 1)
X = pd.get_dummies(X, drop_first = True)

# %%
y.shape, X.shape
# Out:
# ((2218,), (2218, 189))

# %% [markdown]
# ### Split the data into test and train subsamples

# %%
from sklearn.model_selection import train_test_split

# dont forget to define your X and y

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=1)

# %% [markdown]
# ### Scale data to prep for model creation

# %%
#scale data
from sklearn import preprocessing
import numpy as np
# build scaler based on training data and apply it to test data to then also scale the test data
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,roc_auc_score
from sklearn.metrics import accuracy_score,log_loss
from matplotlib import pyplot

# %% [markdown]
# ### Fit Random Forest Classifier
# The fit model shows an overall accuracy of 80% which is great and indicates our model was effectively able to identify the status of a patients in the South Korea dataset.

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=300, random_state = 1,n_jobs=-1)
model_res = clf.fit(X_train_scaled, y_train)
y_pred = model_res.predict(X_test_scaled)
y_pred_prob = model_res.predict_proba(X_test_scaled)
lr_probs = y_pred_prob[:,1]
ac = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')
cm = confusion_matrix(y_test, y_pred)

print('Random Forest: Accuracy=%.3f' % (ac))

print('Random Forest: f1-score=%.3f' % (f1))
# Out:
# Random Forest: Accuracy=0.842
# Random Forest: f1-score=0.810

# %% [markdown]
# ### Create Confusion Matrix Plots
# Confusion matrices are great ways to review your model performance for a multi-class classification problem. Being able to identify which class the misclassified observations end up in is a great way to determine if you need to build additional features to improve your overall model. In the example below we plot a regular counts confusion matrix as well as a weighted percent confusion matrix. The percent confusion matrix is particulary helpful when you have unbalanced class sizes.

# %%
y_test.value_counts()
# Out:
# isolated    351
# released     69
# Unknown      17
# deceased      7
# Name: state, dtype: int64

# %%
class_names=['Unknown', 'deceased','isolated', 'released'] # name  of classes

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()


# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(6,6))

plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
#plt.savefig('figures/RF_cm_multi_class.png')

# Plot normalized confusion matrix
plt.figure(figsize=(6,6))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')
#plt.savefig('figures/RF_cm_proportion_multi_class.png', bbox_inches="tight")
plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 14   0   3   0]
#  [  0   6   1   0]
#  [  0   0 341  10]
#  [  0   0  56  13]]
# Normalized confusion matrix
# [[0.82 0.   0.18 0.  ]
#  [0.   0.86 0.14 0.  ]
#  [0.   0.   0.97 0.03]
#  [0.   0.   0.81 0.19]]

# %% [markdown]
# ### Plot feature importances
# The random forest algorithm can be used as a regression or classification model. In either case it tends to be a bit of a black box, where understanding what's happening under the hood can be difficult. Plotting the feature importances is one way that you can gain a perspective on which features are driving the model predictions.

# %%
feature_importance = clf.feature_importances_
# make importances relative to max importance
feature_importance = 100.0 * (feature_importance / feature_importance.max())[:30]
sorted_idx = np.argsort(feature_importance)[:30]

pos = np.arange(sorted_idx.shape[0]) + .5
print(pos.size)
sorted_idx.size
plt.figure(figsize=(10,10))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, X.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()
# Out:
# 30

# %% [markdown]
# The popularity of random forest is primarily due to how well it performs in a multitude of data situations. It tends to handle highly correlated features well, where as a linear regression model would not. In this case study we demonstrate the performance ability even with only a few features and almost all of them being highly correlated with each other.
# Random Forest is also used as an efficient way to investigate the importance of a set of features with a large data set. Consider random forest to be one of your first choices when building a decision tree, especially for multiclass classifications.

# %%
estimator = model_res.estimators_[1]

from sklearn.tree import export_graphviz
# Export as dot file
export_graphviz(estimator, out_file='treeCovid.dot', 
                feature_names = X.columns,
                class_names = class_names,
                rounded = True, proportion = False, 
                precision = 2, filled = True)

# Convert to png using system command (requires Graphviz)
from subprocess import call
call(['dot', '-Tpng', 'treeCovid.dot', '-o', 'treeCovid.png', '-Gdpi=600'])

# Display in jupyter notebook
from IPython.display import Image
Image(filename = 'treeCovid.png')
