# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.style as style
plt.rcParams['figure.figsize'] = (15, 12)
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
intro = pd.read_excel('2020wahealth.xlsx', sheet_name = 0, header = 18,
                      names = ['Measure', 'Data Elements', 'Description'], 
                      index_col = [0,1]
)
intro.head(30)
# Out:
#                                                                                                              Description
# Measure                   Data Elements
# Geographic identifiers    FIPS                                                   Federal Information Processing Standard
#                           State                                                                                      NaN
#                           County                                                                                     NaN
# Premature death           Deaths                                                                    Number of deaths <75
#                           Years of Potential Life Lost Rate                           Age-adjusted YPLL rate per 100,000
#                           95% CI - Low                                 95% confidence interval reported by National C...
#                           95% CI - High                                                                              NaN
#                           Z-Score                                      (Measure - Average of state counties)/(Standar...
#                           YPLL Rate (AIAN)                             Age-adjusted YPLL rate per 100,000 for non-His...
#                           YPLL Rate (AIAN) 95% CI - Low                                          95% confidence interval
#                           YPLL Rate (AIAN) 95% CI - High                                                             NaN
#                           YPLL Rate (Asian)                            Age-adjusted YPLL rate per 100,000 for non-His...
#                           YPLL Rate (Asian) 95% CI - Low                                         95% confidence interval
#                           YPLL Rate (Asian) 95% CI - High                                                            NaN
#                           YPLL Rate (Black)                            Age-adjusted YPLL rate per 100,000 for non-His...
#                           YPLL Rate (Black) 95% CI - Low                                         95% confidence interval
#                           YPLL Rate (Black) 95% CI - High                                                            NaN
#                           YPLL Rate (Hispanic)                          Age-adjusted YPLL rate per 100,000 for Hispanics
#                           YPLL Rate (Hispanic) 95% CI - Low                                      95% confidence interval
#                           YPLL Rate (Hispanic) 95% CI - High                                                         NaN
#                           YPLL Rate (White)                            Age-adjusted YPLL rate per 100,000 for non-His...
#                           YPLL Rate (White) 95% CI - Low                                         95% confidence interval
#                           YPLL Rate (White) 95% CI - High                                                            NaN
# Poor or fair health       % Fair or Poor Health                        Percentage of adults that report fair or poor ...
#                           95% CI - Low                                         95% confidence interval reported by BRFSS
#                           95% CI - High                                                                              NaN
#                           Z-Score                                      (Measure - Average of state counties)/(Standar...
# Poor physical health days Average Number of Physically Unhealthy Days  Average number of reported physically unhealth...
#                           95% CI - Low                                         95% confidence interval reported by BRFSS
#                           95% CI - High                                                                              NaN
