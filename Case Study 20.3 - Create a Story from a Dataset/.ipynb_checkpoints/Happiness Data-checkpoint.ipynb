# %% [markdown]
# # Does Money Buy Happiness?

# %% [markdown]
# the plan
# - i need to build a ppt
#  - the q is does money buy happines
#  - begin with a slide with all features plotted

# %% [markdown]
# Ever since the modern human existed, he was in a permanent pursuit of Happiness. And one of the biggest question asked when it comes to Happiness is **"Does Money Buy Happiness?"**

# %% [markdown]
# The intended audience for this story presentation is **the Internet**. I choose it because I want the presentation to be one focused on the findings and not on the techinical procedures or business or financial impact of my findings.

# %% [markdown]
# >  *The World Happiness Report is a landmark survey of the state of global happiness. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.[(Kaggle Dataset Description)](https://www.kaggle.com/ajaypalsinghlo/world-happiness-report-2021)*

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.style as style
plt.rcParams['figure.figsize'] = (15, 10)
import seaborn as sns
sns.set_theme(style="whitegrid")

# %% [markdown]
# > The happiness scores and rankings use data from the Gallup World Poll. The columns following the happiness score estimate the extent to which each of six factors – **economic production, social support, life expectancy, freedom, absence of corruption, and generosity** – contribute to making life evaluations higher in each country than they are in a hypothetical country that has values equal to the world’s lowest national averages for each of the six factors.

# %%
df21 = pd.read_csv('world-happiness-report-2021.csv')
df21 = df21[['Country name', 'Regional indicator', 'Ladder score',
            'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
            'Freedom to make life choices', 'Generosity','Perceptions of corruption']]
df21['Happiness score'] = df21['Ladder score']
df21.drop('Ladder score', axis = 1, inplace = True)
df21
# Out:
#     Country name  Regional indicator  Logged GDP per capita  Social support  \
# 0        Finland      Western Europe                 10.775           0.954
# 1        Denmark      Western Europe                 10.933           0.954
# 2    Switzerland      Western Europe                 11.117           0.942
# 3        Iceland      Western Europe                 10.878           0.983
# 4    Netherlands      Western Europe                 10.932           0.942
# ..           ...                 ...                    ...             ...
# 144      Lesotho  Sub-Saharan Africa                  7.926           0.787
# 145     Botswana  Sub-Saharan Africa                  9.782           0.784
# 146       Rwanda  Sub-Saharan Africa                  7.676           0.552
# 147     Zimbabwe  Sub-Saharan Africa                  7.943           0.750
# 148  Afghanistan          South Asia                  7.695           0.463
#
# ...

# %%
sns.barplot(x = 'Regional indicator', y = 'Happiness score', data = df21, ci = None, palette = colormap)
plt.xticks(rotation = 20)
plt.title('Happiness Score averages per region')
plt.ylabel('Happiness')
# Out:
# Text(0, 0.5, 'Happiness')

# %%
df21.groupby('Regional indicator').count()['Country name'].sort_values().plot(kind= 'pie', startangle = 90)
plt.title('Number of countries per region')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
rousa = df21.iloc[[18,45,148],:]
rousa = rousa.T
rousa.columns = ['United States','Romania', 'Afghanistan']
rousa.drop(['Country name','Regional indicator'],axis = 0, inplace = True)
rousa
# Out:
#                              United States Romania Afghanistan
# Logged GDP per capita               11.023  10.284       7.695
# Social support                        0.92   0.832       0.463
# Healthy life expectancy               68.2  67.355      52.493
# Freedom to make life choices         0.837   0.845       0.382
# Generosity                           0.098  -0.219      -0.102
# Perceptions of corruption            0.698   0.938       0.924
# Hapiness score                       6.951    6.14       2.523

# %%
rousa.plot(kind = 'barh')
plt.title('General Happiness was calculated based on 6 factors')
# Out:
# Text(0.5, 1.0, 'General Happiness was calculated based on 6 factors')

# %%
df21['Regional indicator'].unique()
# Out:
# array(['Western Europe', 'North America and ANZ',
#        'Middle East and North Africa', 'Latin America and Caribbean',
#        'Central and Eastern Europe', 'East Asia', 'Southeast Asia',
#        'Commonwealth of Independent States', 'Sub-Saharan Africa',
#        'South Asia'], dtype=object)

# %%
region_happiness = df21.groupby('Regional indicator').mean()['Happiness score'].sort_values(ascending = False)
region_happiness
# Out:
# Regional indicator
# North America and ANZ                 7.128500
# Western Europe                        6.914905
# Central and Eastern Europe            5.984765
# Latin America and Caribbean           5.908050
# East Asia                             5.810333
# Commonwealth of Independent States    5.467000
# Southeast Asia                        5.407556
# Middle East and North Africa          5.219765
# Sub-Saharan Africa                    4.494472
# South Asia                            4.441857
# Name: Ladder score, dtype: float64

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.countplot(y = 'Regional indicator', data = df21, palette = 'bwr',  order=region_happiness.index)
plt.title('South Asia and Sub-Saharan Africa are the most unhappy regions while North America and Western Europe are the happiest')
plt.xlabel('Number of countries in the region')
plt.ylabel('Regions ranked by their Happiness')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-313-4341dd60e12f> in <module>
#       4 plt.xlabel('Number of countries in the region')
#       5 plt.ylabel('Regions ranked by their Happiness')
# ----> 6 plt.colorbar()
#
# E:\Anaconda\lib\site-packages\matplotlib\pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2186         mappable = gci()
#    2187         if mappable is None:
# -> 2188             raise RuntimeError('No mappable was found to use for colorbar '
#    2189                                'creation. First define a mappable such as '
#    2190                                'an image (with imshow) or a contour set ('
#
# RuntimeError: No mappable was found to use for colorbar creation. First define a mappable such as an image (with imshow) or a contour set (with contourf).

# %%
df21
# Out:
#     Country name  Regional indicator  Logged GDP per capita  Social support  \
# 0        Finland      Western Europe                 10.775           0.954
# 1        Denmark      Western Europe                 10.933           0.954
# 2    Switzerland      Western Europe                 11.117           0.942
# 3        Iceland      Western Europe                 10.878           0.983
# 4    Netherlands      Western Europe                 10.932           0.942
# ..           ...                 ...                    ...             ...
# 144      Lesotho  Sub-Saharan Africa                  7.926           0.787
# 145     Botswana  Sub-Saharan Africa                  9.782           0.784
# 146       Rwanda  Sub-Saharan Africa                  7.676           0.552
# 147     Zimbabwe  Sub-Saharan Africa                  7.943           0.750
# 148  Afghanistan          South Asia                  7.695           0.463
#
# ...

# %%
top20h = df21[['Country name', 'Regional indicator','Happiness score','Logged GDP per capita' ]].sort_values('Happiness score', ascending = False).head(20)

# %%
colormap = {'Western Europe': 'blue', 
            'North America and ANZ': 'green',
            'Middle East and North Africa': 'orange',
            'Latin America and Caribbean': 'purple',
           'Central and Eastern Europe':'cyan', 
            'East Asia': 'crimson', 
            'Southeast Asia': 'salmon',
           'Commonwealth of Independent States':'lime',
            'Sub-Saharan Africa':'gold',
           'South Asia':'orangered'}

# %%
bot20h = df21[['Country name', 'Regional indicator','Happiness score','Logged GDP per capita' ]].sort_values('Happiness score', ascending = False).tail(20)

# %%
fig, ax = plt.subplots(figsize=(6,8))
sns.barplot(x="Happiness score", y="Country name", data=bot20h, palette = 'hot')
plt.xlim(0,10)
plt.title('Most unhappy 20 countries')
# Out:
# (0.0, 10.0)

# %%
fig, ax = plt.subplots(figsize=(6,8))
sns.barplot(x="Happiness score", y="Country name", data=top20h, palette = 'winter')
plt.xlim(0,10)
# Out:
# (0.0, 10.0)

# %%
plt.barh(width = top20h['Happiness score'], y = 'Country name')
plt.yticks(range(20), top20h['Country name'])
# Out:
# ([<matplotlib.axis.YTick at 0x1fa2db40580>,
# ...
#  [Text(0, 0, 'Finland'),
#   Text(0, 1, 'Denmark'),
#   Text(0, 2, 'Switzerland'),
#   Text(0, 3, 'Iceland'),
#   Text(0, 4, 'Netherlands'),
#   Text(0, 5, 'Norway'),
#   Text(0, 6, 'Sweden'),
#   Text(0, 7, 'Luxembourg'),
#   Text(0, 8, 'New Zealand'),
#   Text(0, 9, 'Austria'),
#   Text(0, 10, 'Australia'),
#   Text(0, 11, 'Israel'),
#   Text(0, 12, 'Germany'),
#   Text(0, 13, 'Canada'),
#   Text(0, 14, 'Ireland'),
#   Text(0, 15, 'Costa Rica'),
#   Text(0, 16, 'United Kingdom'),
#   Text(0, 17, 'Czech Republic'),
#   Text(0, 18, 'United States'),
#   Text(0, 19, 'Belgium')])

# %%
sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(6, 6))

# Plot the orbital period with horizontal boxes
sns.boxplot(x="Happiness score", y="Regional indicator", data=df21,
            whis=[0, 100], width=.6, palette="bwr")

# Add in points to show each observation
sns.stripplot(x="Happiness score", y="Regional indicator", data=df21,
              size=4, color=".3", linewidth=0)

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="")
plt.title('In Middle East, Africa and South Asia we can find the biggest differences countries happiness')
sns.despine(trim=True, left=True)

# %%
sns.pairplot(df21)

# %%
sns.heatmap(round(df21.corr(), 2), center = 0, cmap="coolwarm", annot = True, annot_kws={'size': 11})
plt.title('Heatmap of subset containing Non-refundable bookings')
# Out:
# Text(0.5, 1.0, 'Heatmap of subset containing Non-refundable bookings')

# %%
data = df21.select_dtypes('number')
data
# Out:
#      Ladder score  Logged GDP per capita  Social support  \
# 0           7.842                 10.775           0.954
# 1           7.620                 10.933           0.954
# 2           7.571                 11.117           0.942
# 3           7.554                 10.878           0.983
# 4           7.464                 10.932           0.942
# ..            ...                    ...             ...
# 144         3.512                  7.926           0.787
# 145         3.467                  9.782           0.784
# 146         3.415                  7.676           0.552
# 147         3.145                  7.943           0.750
# 148         2.523                  7.695           0.463
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                     72.000                         0.949      -0.098
# 1                     72.700                         0.946       0.030
# ...

# %%
X = data.drop('Happiness score', axis = 1)
y = data['Happiness score']

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X, y)
reg.score(X,y)
# Out:
# 0.7558471374226855

# %%
from matplotlib import cm

coef = reg.coef_

colors = cm.RdBu(coef / float(max(coef)))
plot = plt.scatter(coef, coef, c = coef, cmap = 'RdBu')
plt.clf()
plt.colorbar(plot)
plt.barh(range(len(coef)),coef, color = colors)


plt.yticks(range(len(coef)), labels = X.columns)
plt.show()

# %%
sns.relplot(x = 'Happiness score', y = 'Social support', data = df21,
            size = 'Logged GDP per capita', hue='Logged GDP per capita')

# %%
df21
# Out:
#     Country name  Regional indicator  Logged GDP per capita  Social support  \
# 0        Finland      Western Europe                 10.775           0.954
# 1        Denmark      Western Europe                 10.933           0.954
# 2    Switzerland      Western Europe                 11.117           0.942
# 3        Iceland      Western Europe                 10.878           0.983
# 4    Netherlands      Western Europe                 10.932           0.942
# ..           ...                 ...                    ...             ...
# 144      Lesotho  Sub-Saharan Africa                  7.926           0.787
# 145     Botswana  Sub-Saharan Africa                  9.782           0.784
# 146       Rwanda  Sub-Saharan Africa                  7.676           0.552
# 147     Zimbabwe  Sub-Saharan Africa                  7.943           0.750
# 148  Afghanistan          South Asia                  7.695           0.463
#
# ...

# %%
color = df21['Happiness score']

area = df21['Happiness score']**3

df21.plot.scatter(x = 'Social support',y= 'Freedom to make life choices' ,
                     c = color, colormap=matplotlib.cm.get_cmap('Purples'),
                     s = area, edgecolors = 'k',
                     sharex=False, figsize = (15,6), alpha = 0.5)
plt.title("To increase a nation's happiness level it's required to maximize Social support and freedom \n(bigger & darker means happier)")
#plt.axis(xmin = -10, xmax = 200, ymin = -100, ymax = 2500)
plt.show()

# %%
color = df21['Happiness score']

area = df21['Happiness score']*55

df21.plot.scatter(y = 'Logged GDP per capita',x= 'Social support' ,
                     c = color, colormap=matplotlib.cm.get_cmap('Purples'),
                     s = area, edgecolors = 'k',
                     sharex=False, figsize = (15,6), alpha = 0.5)
#plt.title('Tags features - different questions IDs, total questions in train set and percentage correct')
#plt.axis(xmin = -10, xmax = 200, ymin = -100, ymax = 2500)
plt.show()
